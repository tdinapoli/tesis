# %%
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path

# %%
path = Path("/home/tomi/Documents/academicos/facultad/tesis/tesis/data/2024-06-05")
df = pd.read_pickle(path.glob('*.py')[0])

# %%
plt.plot(df.time, df.ch1, '.-')
plt.xlabel("Longitud de onda (nm)")
plt.ylabel("Cuentas por segundo (1/s)")
plt.grid()
plt.savefig(p / 'figures' / f"{df.attrs["optical_power"]}.png", dpi=300)
plt.show()

# %%
#df1 = pd.read_pickle('data/full_spectrums/350.0_701.0_1.0_0.001_0.130_0.200.pickle')
#df2 = pd.read_pickle('data/full_spectrums/350.0_701.0_1.0_0.0003_0.197_0.300.pickle')
df2 = pd.read_pickle('data/530.0_560.0_1.0_0.001_0.130_0.200.pickle')
#df1

# %%
# %matplotlib inline

# %%
#df.plot()

#plt.plot(df1.wavelength, df1.counts / df1.attrs["integration_time"])
plt.plot(df2.wavelength, df2.counts / df2.attrs["integration_time"])

# %%
df.attrs
# Out:
# {'type': 'emission_spectrum',
#  'excitation_wavelength': None,
#  'starting_wl': 350.0,
#  'ending_wl': 701.0,
#  'wl_step': 1.0,
#  'integration_time': 0.0007799999999999999,
#  'current': 0.2,
#  'optical_power': 0.130205229}
