# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_pickle("data/410_120_3_0.4_0.285207987.pickle")
df.arrival_times
# Out:
# 0       0.000013
# 1       0.000013
# 2       0.000013
# 3       0.000030
# 4       0.000030
#           ...
# 4375    0.000534
# 4376    0.000651
# 4377    0.000651
# 4378    0.000651
# 4379    0.000651
# Name: arrival_times, Length: 4380, dtype: float64

# %%
df2 = pd.read_pickle("data/410_120_3_0.4_0.285530627.pickle")
df2.arrival_times
# Out:
# 0       0.000018
# 1       0.000018
# 2       0.000018
# 3       0.000018
# 4       0.000018
#           ...
# 6215    0.000664
# 6216    0.000664
# 6217    0.000664
# 6218    0.000664
# 6219    0.000664
# Name: arrival_times, Length: 6220, dtype: float64

# %%
bins = np.linspace(0, 0.001, 40)
df.hist(bins=bins, density=True)
df2.hist(bins=bins, density=True)
msr = 125e6
sr = msr/2
bs = 2**14
mt = bs/sr
plt.axvline(mt, linestyle="dashed", color="k")
plt.axvline(2*mt, linestyle="dashed", color="k")
